# %%
import numpy as np
import json

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torch import optim

from gnn_data import GNN_DATA
from pipr_models import PIPRModel

# %% [markdown]
# # 走通流程

# %%
ppi_data = GNN_DATA(ppi_path='./protein_info/protein.actions.SHS27k.STRING.pro2.txt')
# Out:
# 54813it [00:00, 398251.08it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1109595.42it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1332668.51it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1666113.84it/s]

# %%
pseq_path = "./protein_info/protein.SHS27k.sequences.dictionary.pro3.tsv"
vec_path = "./protein_info/vec5_CTC.txt"
ppi_data.get_feature_origin(pseq_path=pseq_path,
                                vec_path=vec_path)
# Out:
# 1553it [00:00, 221888.34it/s]
# protein num: 1553
# protein average length: 528.5151320025757
# protein max & min length: 2517, 51
# acid vector dimension: 13
# 100%|██████████| 1553/1553 [00:00<00:00, 2878.00it/s]
# 100%|██████████| 1553/1553 [00:00<?, ?it/s]

# %%
ppi_label_list = ppi_data.ppi_label_list
ppi_label_list = ppi_label_list[:int(len(ppi_label_list) / 2)]  # ppi pair的label
ppi_list = ppi_data.ppi_list
ppi_list = ppi_list[:int(len(ppi_list) / 2)]  # ppi pair分别记录索引
name2idx = ppi_data.protein_name  # 蛋白名字-索引
idx2name = dict(zip(name2idx.values(), name2idx.keys()))  # 索引-蛋白质
protein_dict = ppi_data.protein_dict  # 蛋白质-序列向量

# %% [markdown]
# 走通了！

# %%
for ppi_index, pair in enumerate(ppi_list):
    p1 = pair[0]
    p2 = pair[1]
    seq1 = protein_dict[idx2name[p1]]
    seq2 = protein_dict[idx2name[p2]]
    seq1 = torch.from_numpy(seq1).float().unsqueeze(0).transpose(1, 2)
    seq2 = torch.from_numpy(seq2).float().unsqueeze(0).transpose(1, 2)
    output = model(seq1, seq2)
    label = ppi_label_list[ppi_index]
    break

# %%
loss_fn = nn.BCEWithLogitsLoss()
label = torch.tensor([label])
output
# Out:
# tensor([[-0.1660,  0.1409,  0.1192, -0.0455,  0.1286, -0.0395, -0.0960]],
#        grad_fn=<AddmmBackward0>)

# %%
loss_fn(output, label.float())
# Out:
# tensor(0.7070, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)

# %% [markdown]
# # 写成Dataset方便loader读取

# %%
class SHS27K(Dataset):
    def __init__(self, ppi_path, pseq_path, vec_path, train_valid_index_path, TRAIN=True):
        super(SHS27K, self).__init__()
        self.TRAIN = TRAIN  # 是训练集还是验证集
        # 这里调用HIGH-PPI项目写好的数据接口
        ppi_data = GNN_DATA(ppi_path)
        ppi_data.get_feature_origin(pseq_path=pseq_path,
                                vec_path=vec_path)
        # 三个字典，方便通过索引获取蛋白质对应的array
        name2idx = ppi_data.protein_name  # 字典，蛋白名字-索引
        self.idx2name = dict(zip(name2idx.values(), name2idx.keys()))  # 反转键值，索引-蛋白
        self.protein_dict = ppi_data.protein_dict  # 蛋白-序列向量
        
        # ppi_list和ppi_label_list是同等长度的，相同索引是对应关系
        ppi_list = ppi_data.ppi_list
        ppi_list = ppi_list[:int(len(ppi_list) / 2)]  # e.g. [0, 1]
        ppi_label_list = ppi_data.ppi_label_list
        ppi_label_list = np.array(ppi_label_list[:int(len(ppi_label_list) / 2)])  # e.g. [0, 1]对应的multi-label
        
        # 读取HIGH-PPI的数据集划分文件
        f = open(train_valid_index_path, "r")
        train_valid_index = json.load(f)
        train_index = train_valid_index['train_index']
        valid_index = train_valid_index['valid_index']
        # 拿到划分后的训练集和验证集
        self.train_ppi_list = [ppi_list[index] for index in train_index]
        self.train_ppi_label_list = [ppi_label_list[index] for index in train_index]
        self.valid_ppi_list = [ppi_list[index] for index in valid_index]
        self.valid_ppi_label_list = [ppi_label_list[index] for index in valid_index]
        
        
    def __getitem__(self, ppi_index):
        label, p1, p2 = None, None, None
        if self.TRAIN:
            label = self.train_ppi_label_list[ppi_index]  # 标签
            p1, p2 = self.train_ppi_list[ppi_index]  # 取出ppi
        else:
            label = self.valid_ppi_label_list[ppi_index]  # 标签
            p1, p2 = self.valid_ppi_list[ppi_index]  # 取出ppi
        seq1 = self.protein_dict[self.idx2name[p1]]
        seq2 = self.protein_dict[self.idx2name[p2]]
        pro2seq = {"p1": seq1, "p2": seq2}
        
        return pro2seq, label
    
    def __len__(self):
        if self.TRAIN:
            return len(self.train_ppi_list)
        else:
            return len(self.valid_ppi_list)

# %%
ppi_path='./protein_info/protein.actions.SHS27k.STRING.pro2.txt'
pseq_path = "./protein_info/protein.SHS27k.sequences.dictionary.pro3.tsv"
vec_path = "./protein_info/vec5_CTC.txt"
train_valid_index_path = "./train_val_split_data/train_val_split_27.json"
train_dataset = SHS27K(ppi_path, pseq_path, vec_path, train_valid_index_path)
valid_dataset = SHS27K(ppi_path, pseq_path, vec_path, train_valid_index_path, TRAIN=False)
# Out:
# 54813it [00:00, 285488.41it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1109992.24it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1332859.27it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1110124.57it/s]
# 1553it [00:00, 221888.34it/s]
# protein num: 1553
# protein average length: 528.5151320025757
# protein max & min length: 2517, 51
# acid vector dimension: 13
# 100%|██████████| 1553/1553 [00:00<00:00, 3253.56it/s]
# 100%|██████████| 1553/1553 [00:00<00:00, 1572231.26it/s]
# 54813it [00:00, 398230.39it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1110080.46it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1665617.12it/s]
# 100%|██████████| 6660/6660 [00:00<00:00, 1332160.08it/s]
# 1553it [00:00, 221895.90it/s]
# protein num: 1553
# protein average length: 528.5151320025757
# protein max & min length: 2517, 51
# acid vector dimension: 13
# 100%|██████████| 1553/1553 [00:00<00:00, 2724.56it/s]
# 100%|██████████| 1553/1553 [00:00<00:00, 1550893.84it/s]

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=2, shuffle=True)
loss_fn = nn.BCEWithLogitsLoss()
model = PIPRModel(input_dim=13, hidden_dim=50, class_num=7).float()
optimizer = optim.Adam(model.parameters(), lr=0.001, amsgrad=True, eps=1e-5)
for pro2seq, label in train_loader:
    seq1 = pro2seq["p1"].transpose(1, 2).float()
    seq2 = pro2seq["p2"].transpose(1, 2).float()
    output = model(seq1, seq2)
    label = label.float()
    loss = loss_fn(output, label)
    print(loss)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# tensor(0.6829, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6790, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6858, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6958, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6929, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6812, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6911, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6878, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6660, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6406, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6977, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8059, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6159, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6248, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6791, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6735, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6226, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6566, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6286, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5226, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7235, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3482, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5700, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8433, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6659, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6726, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6634, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6760, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6126, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6844, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6328, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6310, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6476, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6263, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6223, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6541, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6534, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6097, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6411, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5426, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4529, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4535, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4086, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.7382, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7162, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.0171, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5787, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6101, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6006, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6623, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6278, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6907, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6358, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6349, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6601, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6454, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6558, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6460, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6508, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6705, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6124, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6523, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6333, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6354, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6359, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6101, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7530, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6151, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6303, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6317, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6069, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7129, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5555, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4858, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6021, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5197, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4685, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5277, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3259, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(1.1714, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.9541, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6533, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4589, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5327, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5637, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6416, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6624, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5637, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5519, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6099, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5944, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5673, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6769, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5761, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5256, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5168, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6452, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6921, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5214, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7844, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6053, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5641, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6212, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4401, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4882, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4899, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6266, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6452, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5097, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6971, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7546, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6086, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4700, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6736, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6447, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6930, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7441, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4828, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5746, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6503, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6548, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5626, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6341, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5301, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6736, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5319, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5423, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5081, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6094, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6582, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5593, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5788, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6108, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4953, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4892, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6204, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5552, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4686, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4402, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4229, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6203, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4372, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4118, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8831, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4157, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6845, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6484, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5656, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4446, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7809, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5416, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4340, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6835, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5599, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7088, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6848, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6543, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4699, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5237, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5063, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4856, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5226, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5561, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5365, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6861, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6254, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4724, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4734, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6311, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4956, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4887, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5633, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3836, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5608, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5047, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7853, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3943, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6574, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7488, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7471, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4884, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6929, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7630, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7075, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6262, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4866, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5077, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5071, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6703, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6396, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6319, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6064, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5179, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5337, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6373, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6439, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6109, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5381, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8654, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6232, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6655, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5448, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6674, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6397, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6210, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6625, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6630, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8168, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5553, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6492, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6612, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7452, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5831, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5723, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5596, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6072, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6215, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6970, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6190, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6153, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6819, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5936, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6336, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5361, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5138, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5181, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5387, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5517, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6696, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4997, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5594, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4905, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7006, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8211, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4670, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6630, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5709, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6232, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8351, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4320, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6369, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6779, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4628, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6831, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4996, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8847, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5233, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4519, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4774, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4773, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6453, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4986, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7114, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5530, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5202, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6035, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7995, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7461, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6776, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5510, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7236, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5686, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5720, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5573, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7021, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5315, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5756, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4968, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5135, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4816, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5062, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6782, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4780, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6146, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6195, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6312, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4600, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5625, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4862, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4690, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4735, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4844, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4165, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7485, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4782, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6301, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5951, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4513, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5708, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4364, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4668, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6201, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6702, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5709, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7290, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7544, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4780, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4398, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5792, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6641, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5780, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4827, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4866, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4747, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4723, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4721, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4533, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6875, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5819, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6087, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4895, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4498, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5731, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4449, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4266, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6121, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5507, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6883, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3904, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5041, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4523, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4490, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8745, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6757, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6519, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4526, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7216, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4510, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5590, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4298, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5602, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6381, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6920, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6869, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4696, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5208, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4804, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6127, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4806, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6755, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6396, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5908, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4550, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4716, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4764, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7530, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5943, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4715, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4637, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5622, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6354, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5532, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8727, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5478, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4443, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4645, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6042, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4711, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4771, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6126, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4589, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5948, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4460, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4524, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5668, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4419, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6375, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6178, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7091, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6129, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4652, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4486, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4130, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6277, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4006, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4156, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7457, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5370, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4824, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4652, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3871, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4583, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5154, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4261, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4460, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5573, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8580, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5237, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4466, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4854, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4935, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5960, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6113, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4655, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8909, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7445, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8434, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5767, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4583, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6378, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4694, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4728, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6051, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4585, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6271, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5435, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6710, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4998, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4997, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6333, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5477, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5053, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6222, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4805, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4870, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5013, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4969, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5576, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6469, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4165, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4091, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7359, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4041, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7057, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7697, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5778, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4007, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5045, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7352, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6920, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6977, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5484, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7880, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6781, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7400, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5113, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6959, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5307, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4949, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5744, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5764, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6207, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6187, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6159, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5229, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6270, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4991, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5186, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5207, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5118, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7522, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5771, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5939, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4585, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5741, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4905, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4716, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6207, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5142, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6375, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5448, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7567, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6999, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4303, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4614, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4615, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4591, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4076, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6964, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4172, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4152, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5693, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4239, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6237, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8836, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4647, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5876, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6259, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4252, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5487, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8749, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6512, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4560, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4227, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4536, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7518, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5920, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5442, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5033, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4508, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4749, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6767, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7012, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6152, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8039, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6519, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4474, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6957, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5602, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7861, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5022, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5789, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6571, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5110, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6978, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5102, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4990, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6925, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4726, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4703, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5867, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6799, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5299, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5210, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7166, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5602, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5027, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4664, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6297, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4758, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5801, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6968, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4312, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5691, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4944, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4001, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6255, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7476, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7538, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5752, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4474, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6916, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7281, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4333, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4012, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7444, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5170, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4841, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5588, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6329, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5472, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5571, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6244, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6288, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4114, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6978, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5698, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5457, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6606, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4729, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7532, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5499, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7317, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5232, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5744, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4654, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5261, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6580, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6629, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6085, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4927, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4640, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6510, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6312, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4704, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5722, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3951, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5408, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5705, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6769, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5021, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4163, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4764, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5827, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4608, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3687, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5288, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4456, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6708, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5833, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5041, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4495, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3958, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5261, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4131, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.3876, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4684, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4438, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7327, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4855, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4723, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8784, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5800, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4729, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8064, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7671, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4737, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4567, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4609, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5981, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.9268, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4418, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5571, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5787, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4745, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4843, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5755, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5992, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5586, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4791, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5160, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.8051, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6563, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7156, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6874, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.7236, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4937, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5058, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5726, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.5660, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6155, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6262, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.6182, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# tensor(0.4694, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Codefield\Graduation Project\HIGH-PPI\PIPR explore.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/d%3A/Codefield/Graduation%20Project/HIGH-PPI/PIPR%20explore.ipynb#X30sZmlsZQ%3D%3D?line=10'>11</a> print(loss)
#      <a href='vscode-notebook-cell:/d%3A/Codefield/Graduation%20Project/HIGH-PPI/PIPR%20explore.ipynb#X30sZmlsZQ%3D%3D?line=11'>12</a> optimizer.zero_grad()
# ---> <a href='vscode-notebook-cell:/d%3A/Codefield/Graduation%20Project/HIGH-PPI/PIPR%20explore.ipynb#X30sZmlsZQ%3D%3D?line=12'>13</a> loss.backward()
#      <a href='vscode-notebook-cell:/d%3A/Codefield/Graduation%20Project/HIGH-PPI/PIPR%20explore.ipynb#X30sZmlsZQ%3D%3D?line=13'>14</a> optimizer.step()
#
# File d:\miniconda3\envs\play\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File d:\miniconda3\envs\play\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
